# %%
item_price = 99
amount = 0
discount = 0
total_price = 0

amount = int(input("How many would you like to purchase?"))

if (amount >= 10 and amount <= 19):
  discount = .1
elif (amount >=20 and amount <= 49):
  discount = .2
elif (amount >=50 and amount <= 99):
  discount = .3
elif (amount >=100):
  discount = .4

#print the discount
print(f"The discount is {discount*100}%")

#calculate and print the total price
total_price = amount*item_price*(1-discount)
print(f"The total price is {total_price:,.2f}")
# Out:
# How many would you like to purchase?34
# The discount is 20.0%
# The total price is 2,692.80

# %%
weight = 0
rate_per_pound = 0

weight = float(input("How much does your package weigh?"))

if(weight <= 2):
  rate_per_pound = 1.50
elif (weight >2 and weight <= 6):
  rate_per_pound = 3
elif (weight >6 and weight <=10):
  rate_per_pound = 4
elif (weight >10):
  rate_per_pound = 4.75

total_price = weight*rate_per_pound
print(f"The rate is ${total_price:.2f}")
# Out:
# How much does your package weigh?5
# The rate is $15.00
